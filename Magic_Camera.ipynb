# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdiikebede/-Modern-UI-UX-Landing-Page-Design/blob/main/Magic_Camera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cols=["flength","fsize","fconc","fAsym","fM3Long","FMJTrains","fAlpha","fDist","class"]
df=pd.read_csv('magic04.data',names=cols)
df.head()
# Out:
#                    flength   fsize   fconc     fAsym  fM3Long  FMJTrains  \
# 28.7967  16.0021    2.6449  0.3918  0.1982   27.7004  22.0110    -8.2027
# 31.6036  11.7235    2.5185  0.5303  0.3773   26.2722  23.8238    -9.9574
# 162.0520 136.0310   4.0612  0.0374  0.0187  116.7410 -64.8580   -45.2160
# 23.8172  9.5728     2.3385  0.6147  0.3922   27.2107  -6.4633    -7.1513
# 75.1362  30.9205    3.1611  0.3168  0.1832   -5.5277  28.5525    21.8393
#
#                     fAlpha     fDist class
# 28.7967  16.0021   40.0920   81.8828     g
# 31.6036  11.7235    6.3609  205.2610     g
# 162.0520 136.0310  76.9600  256.7880     g
# 23.8172  9.5728    10.4490  116.7370     g
# 75.1362  30.9205    4.6480  356.4620     g

# %%
df['class']=(df['class']=='g').astype(int)

# %%
df.head()
# Out:
#                    flength   fsize   fconc     fAsym  fM3Long  FMJTrains  \
# 28.7967  16.0021    2.6449  0.3918  0.1982   27.7004  22.0110    -8.2027
# 31.6036  11.7235    2.5185  0.5303  0.3773   26.2722  23.8238    -9.9574
# 162.0520 136.0310   4.0612  0.0374  0.0187  116.7410 -64.8580   -45.2160
# 23.8172  9.5728     2.3385  0.6147  0.3922   27.2107  -6.4633    -7.1513
# 75.1362  30.9205    3.1611  0.3168  0.1832   -5.5277  28.5525    21.8393
#
#                     fAlpha     fDist  class
# 28.7967  16.0021   40.0920   81.8828      1
# 31.6036  11.7235    6.3609  205.2610      1
# 162.0520 136.0310  76.9600  256.7880      1
# 23.8172  9.5728    10.4490  116.7370      1
# 75.1362  30.9205    4.6480  356.4620      1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['flength'].plot(kind='hist', bins=20, title='flength')
# ...
